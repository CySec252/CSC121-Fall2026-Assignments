# %% [markdown]
# <a href="https://colab.research.google.com/github/CySec252/CSC121-Fall2026-Assignments/blob/main/Week5/cinema_pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None needed)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
# 2. Base price logic:
#    - If age <= 12 or age >= 65: base price is 8.00
#    - Otherwise: base price is 12.00
# 3. Matinee discount logic:
#    - If hour < 17: subtract 2.00 from the price
# 4. Output:
#    - Print formatted string: "Your ticket price is $[price]."

# PROGRAM LOGIC
# 1. Prompt user for age and convert to int
# 2. Prompt user for movie hour (0-23) and convert to int
# 3. Call calculate_ticket(age, hour)
