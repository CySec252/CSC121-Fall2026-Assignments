# %% [markdown]
# <a href="https://colab.research.google.com/github/CySec252/CSC121-Fall2026-Assignments/blob/main/Week4/Week4_team_profile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
def print_bio(name, age, goal):
    border = "*" * 35
    print(border)
    print(f"Name: {name}, Age: {age}, Goal: {goal}")
    print(border)
# 1. Define print_bio with three parameters: name, age, and goal.
# 2. Inside the function, use string multiplication (*) for a border line.
# 3. Print the bio details using the parameter names.

# PROGRAM LOGIC
# 1. Call print_bio using my own info (Gerald, 48, Master Python and complete cybersecurity degree).
print_bio("Gerald", 48, "Master Python and complete cybersecurity degree.")

# 2. Call print_bio using Josh Allen (Josh Allen, 30, Win a Super Bowl with the Buffalo Bills).
print_bio("Josh Allen", 30, "Win a Super Bowl with the Buffalo Bills.")

# 3. Call print_bio using King (King, 31, Win the King of Iron Fist Tournament).
print_bio("King", 31, "Win the King of Iron Fist Tournament.")
# Out:
# ***********************************
# Name: Gerald, Age: 48, Goal: Master Python and complete cybersecurity degree.
# ***********************************
# ***********************************
# Name: Josh Allen, Age: 30, Goal: Win a Super Bowl with the Buffalo Bills.
# ***********************************
# ***********************************
# Name: King, Age: 31, Goal: Win the King of Iron Fist Tournament.
# ***********************************
