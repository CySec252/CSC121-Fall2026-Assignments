# %% [markdown]
# <a href="https://colab.research.google.com/github/CySec252/CSC121-Fall2026-Assignments/blob/main/Week3Week3mybio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Course: CSC-121 Python Programming
# Assignment: Chapter 2 - Professional Bio Generator

# --- LOGIC & PSEUDOCODE ---
# 1. Assign values to name, goal, birth_year, and current_year.
# 2. Calculate age by subtracting birth_year from current_year.
# 3. Print the top border line using string multiplication (*).
# 4. Print the bio sentences.
# 5. Print the bottom border line using string multiplication (*).

# --- IMPLEMENTATION ---
# Variables
name = "Gerald Smallwood"
goal = "become a cybersecurity professional"
birth_year = 1978
current_year = 2026

# Calculation
age = current_year -birth_year

# Top border and first print check
border = "=" * 49
print(border)
print(f"My name is Gerald Smallwood and I am 48 yeard old")
print(border)
# Out:
# ...
# My name is Gerald Smallwood and I am 48 yeard old
# ...
